# %%
from football_model import (
    show_prediction,
    simulate_knockout,
    simulate_match,
    create_match_features,
    predict_match
)

# %%
show_prediction('Argentina','Morocco')
# Out:
# Argentina vs Morocco
#
# Argentina Win: 43.48%
# Draw : 16.04%
# Morocco Win: 40.48%

# %%
simulate_knockout('United States','DR Congo')
# Out:
# 'United States'

# %%
show_prediction('Curaçao','Brazil')
# Out:
# Curaçao vs Brazil
#
# Curaçao Win: 3.55%
# Draw : 5.48%
# Brazil Win: 90.97%
